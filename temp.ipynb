# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
# Import tqdm for progress bar in for notebok
from tqdm import tqdm_notebook as tqdm

BATTERY = 'V4'

# %%
# df = df.drop(['soh_interpolated_var', 'soh_interpolated_skew', 'soh_interpolated_min', 'soh_interpolated_max'], axis=1)
# Read .mat file
mat = scipy.io.loadmat(f'battery datasets/Stanford/cycle01/{BATTERY}.mat')
df1 = pd.DataFrame()
for key in mat.keys():
    if key not in ["__header__", "__version__", "__globals__"]:
        df1[key] = mat[key].flatten()

sns.set_style('darkgrid')
df1.set_index('t_full_vec_M1_NMC25degC').plot(subplots=True, figsize=(10, 20))
# Out:
# array([<Axes: xlabel='t_full_vec_M1_NMC25degC'>,
#        <Axes: xlabel='t_full_vec_M1_NMC25degC'>,
#        <Axes: xlabel='t_full_vec_M1_NMC25degC'>,
#        <Axes: xlabel='t_full_vec_M1_NMC25degC'>,
#        <Axes: xlabel='t_full_vec_M1_NMC25degC'>], dtype=object)

# %%
# df = df.drop(['soh_interpolated_var', 'soh_interpolated_skew', 'soh_interpolated_min', 'soh_interpolated_max'], axis=1)
# Read .mat file
mat = scipy.io.loadmat(f'battery datasets/Stanford/cycle10/{BATTERY}.mat')
df1 = pd.DataFrame()
for key in mat.keys():
    if key not in ["__header__", "__version__", "__globals__"]:
        df1[key] = mat[key].flatten()

sns.set_style('darkgrid')
df1.set_index('t_full_vec_M1_NMC25degC').plot(subplots=True, figsize=(10, 20))
# Out:
# array([<Axes: xlabel='t_full_vec_M1_NMC25degC'>,
#        <Axes: xlabel='t_full_vec_M1_NMC25degC'>,
#        <Axes: xlabel='t_full_vec_M1_NMC25degC'>,
#        <Axes: xlabel='t_full_vec_M1_NMC25degC'>,
#        <Axes: xlabel='t_full_vec_M1_NMC25degC'>], dtype=object)

# %%
# df = df.drop(['soh_interpolated_var', 'soh_interpolated_skew', 'soh_interpolated_min', 'soh_interpolated_max'], axis=1)
# Read .mat file
df = pd.read_csv(f'battery datasets/Stanford/interpolated/V4_day.csv')


sns.set_style('darkgrid')
df.set_index('day').plot(subplots=True, figsize=(10, 20))
# Out:
# array([<Axes: xlabel='day'>, <Axes: xlabel='day'>, <Axes: xlabel='day'>,
#        <Axes: xlabel='day'>, <Axes: xlabel='day'>, <Axes: xlabel='day'>,
#        <Axes: xlabel='day'>, <Axes: xlabel='day'>, <Axes: xlabel='day'>,
#        <Axes: xlabel='day'>, <Axes: xlabel='day'>, <Axes: xlabel='day'>,
#        <Axes: xlabel='day'>, <Axes: xlabel='day'>, <Axes: xlabel='day'>,
#        <Axes: xlabel='day'>, <Axes: xlabel='day'>, <Axes: xlabel='day'>,
#        <Axes: xlabel='day'>, <Axes: xlabel='day'>, <Axes: xlabel='day'>,
#        <Axes: xlabel='day'>], dtype=object)
